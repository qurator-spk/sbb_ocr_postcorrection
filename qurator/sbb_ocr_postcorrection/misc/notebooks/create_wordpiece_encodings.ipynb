# %%
import numpy as np
import os
home_dir = os.path.expanduser('~')
import sys

sys.path.append(home_dir + '/Qurator/mono-repo/sbb_ocr_correction/qurator/sbb_ocr_correction/mt/feature_extraction/wordpiece_encoding')
from encoding import encode_sequence
from wordpiece import WordpieceVocabGenerator
from tokenization import WordpieceTokenizer

sys.path.append(home_dir + '/Qurator/mono-repo/sbb_ocr_correction/qurator/sbb_ocr_correction/data_preproc/dta')
from database import load_alignments_from_sqlite

# %%
#path definitions
db_path = home_dir + '/Qurator/mono-repo/sbb_ocr_correction/qurator/sbb_ocr_correction/data_preproc/dta/data/aligned_corpus.db'
encoded_ocr_path = home_dir + '/Qurator/mono-repo/sbb_ocr_correction/qurator/sbb_ocr_correction/mt/features/encoded_ocr.npy'
encoded_gt_path = home_dir + '/Qurator/mono-repo/sbb_ocr_correction/qurator/sbb_ocr_correction/mt/features/encoded_gt.npy'

# %%
aligned_data, aligned_data_as_df, headers = load_alignments_from_sqlite(db_path)
len(aligned_data)
# Out:
# 1114

# %%
def create_wordpiece_encodings(aligned_data, print_examples=False):
    '''
    
    '''
    g = WordpieceVocabGenerator(max_wordpiece_length=3)
    g.generate_vocab_counts(aligned_data)
    wordpiece_vocab = g.wordpiece_vocab

    encoding = g.create_vocab_encoding(token_threshold=100)

    tok = WordpieceTokenizer(encoding, token_delimiter="<WSC>", unknown_char="<UNK>")

    ocr_encodings = []
    gt_encodings = []
    for alignment in aligned_data:
        tokenized_ocr = tok.tokenize(alignment[0], print_examples)
        tokenized_gt = tok.tokenize(alignment[1], print_examples)

        ocr_encodings.append(encode_sequence(tokenized_ocr, encoding))
        gt_encodings.append(encode_sequence(tokenized_gt, encoding))

    ocr_encodings = np.array(ocr_encodings)
    gt_encodings = np.array(gt_encodings)
    
    return ocr_encodings, gt_encodings

# %%
ocr_encodings, gt_encodings = create_wordpiece_encodings(aligned_data, print_examples=True)
# Out:
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'l', 'i', 'c', 'h', 'e']
# Tokens:  ['C', 'hri', 'ſt', 'lic', 'he']
# ------
# Chars:  ['L', 'e', 'i', 'c', 'h', '⸗']
# Tokens:  ['L', 'ei', 'ch', '⸗']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['E', 'h', 'r', 'e', 'n', '⸗', 'P', 'r', 'e', 'd', 'i', 'g', 't']
# Tokens:  ['E', 'hre', 'n', '⸗', 'P', 're', 'di', 'g', 't']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'l', 'i', 'c', 'h', 'e']
# Tokens:  ['C', 'hri', 'ſt', 'lic', 'he']
# ------
# Chars:  ['L', 'e', 'i', 'c', 'h', '-']
# Tokens:  ['L', 'ei', 'ch', '-']
# ------
# Chars:  ['E', 'h', 'r', 'e', 'n', '-', 'P', 'r', 'e', 'd', 'i', 'g', 't']
# Tokens:  ['E', 'hre', 'n', '-', 'P', 're', 'di', 'g', 't']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['b', 'e', 'y']
# Tokens:  ['be', 'y']
# ------
# Chars:  ['E', 'r', 'b', 'a', 'r', 'n']
# Tokens:  ['E', 'r', 'b', 'ar', 'n']
# ------
# Chars:  ['T', 'h', 'u', '⸗']
# Tokens:  ['T', 'h', 'u', '⸗']
# ------
# Chars:  ['E', 'r', 'b', 'a', 'r', 'n']
# Tokens:  ['E', 'r', 'b', 'ar', 'n']
# ------
# Chars:  ['E', 'h', 'r']
# Tokens:  ['E', 'hr']
# ------
# Chars:  ['T', 'h', 'u', '-']
# Tokens:  ['T', 'h', 'u', '-']
# ------
# Chars:  ['B', 'A', 'R', 'B', 'A', 'R', 'A']
# Tokens:  ['B', 'A', 'R', 'B', 'A', 'R', 'A']
# ------
# Chars:  ['P', 'o', 't', 't', 'e', 'r', 'm', 'a', 'n', 'n', 'i', 'n']
# Tokens:  ['P', 'ott', 'er', 'm', 'an', 'ni', 'n']
# ------
# Chars:  ['P', 'o', 't', 't', 'e', 'r', 'm', 'a', 'n', 'n', 'i', 'n', '/']
# Tokens:  ['P', 'ott', 'er', 'm', 'an', 'ni', 'n/']
# ------
# Chars:  ['D', 'e', 's']
# Tokens:  ['D', 'es']
# ------
# Chars:  ['N', 'a', 'm', 'h', 'a', 'f', 'f', 't', 'e', 'n']
# Tokens:  ['N', 'a', 'm', 'ha', 'ff', 'ten']
# ------
# Chars:  ['E', 'h', 'r', 'e', 'n', 'v', 'e', 'ſ', 't', 'e', 'n']
# Tokens:  ['E', 'hre', 'n', 'v', 'eſ', 'ten']
# ------
# Chars:  ['N', 'a', 'm', 'h', 'a', 'f', 'f', 't', 'e', 'n']
# Tokens:  ['N', 'a', 'm', 'ha', 'ff', 'ten']
# ------
# Chars:  ['S', 'e', 'i', 'f', 'e', 'r', 't', 's']
# Tokens:  ['S', 'ei', 'f', 'ert', 's']
# ------
# Chars:  ['B', 'u', 'ͤ', 'r', 'g', 'e', 'r', 's']
# Tokens:  ['B', 'uͤ', 'r', 'ge', 'r', 's']
# ------
# Chars:  ['C', 'a', 'ſ', 'p', 'a', 'r']
# Tokens:  ['C', 'a', 'ſ', 'p', 'ar']
# ------
# Chars:  ['S', 'e', 'i', 'f', 'e', 'r', 't', 's']
# Tokens:  ['S', 'ei', 'f', 'ert', 's']
# ------
# Chars:  ['H', 'a', 'n', 'd', 'e', 'l', 's', '-']
# Tokens:  ['H', 'and', 'el', 's', '-']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['w', 'o', 'l', 'v', 'e', 'r', 'o', 'r', 'd', 'n', 'e', 't', 'e', 'n']
# Tokens:  ['w', 'o', 'l', 'ver', 'or', 'd', 'ne', 'ten']
# ------
# Chars:  ['H', 'o', 'f', 'f', '⸗']
# Tokens:  ['H', 'o', 'ff', '⸗']
# ------
# Chars:  ['w', 'o', 'l', 'v', 'e', 'r', 'o', 'r', 'd', 'n', 'e', 't', 'e', 'n']
# Tokens:  ['w', 'o', 'l', 'ver', 'or', 'd', 'ne', 'ten']
# ------
# Chars:  ['K', 'o', 'ͤ', 'n', 'i', 'g', 'l', '.']
# Tokens:  ['K', 'o', 'ͤ', 'ni', 'g', 'l', '.']
# ------
# Chars:  ['E', 'h', 'e', 'f', 'r', 'a', 'w', 'e', 'n']
# Tokens:  ['E', 'he', 'f', 'ra', 'we', 'n']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['g', 'e', 'l', 'i', 'e', 'b', 't', 'e', 'n']
# Tokens:  ['ge', 'li', 'eb', 'ten']
# ------
# Chars:  ['i', 'm']
# Tokens:  ['i', 'm']
# ------
# Chars:  ['e', 'n', 't', 'ſ', 'c', 'h', 'l', 'a', 'f', 'f', 'e', 'n']
# Tokens:  ['en', 't', 'ſch', 'l', 'a', 'ff', 'en']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'n']
# Tokens:  ['H', 'E', 'r', 'r', 'n']
# ------
# Chars:  ['e', 'n', 't', 'ſ', 'c', 'h', 'l', 'a', 'f', 'f', 'e', 'n']
# Tokens:  ['en', 't', 'ſch', 'l', 'a', 'ff', 'en']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['2', '8', '.']
# Tokens:  ['2', '8', '.']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'i', 'e', 'ſ', 'e', 's']
# Tokens:  ['die', 'ſe', 's']
# ------
# Chars:  ['1', '6']
# Tokens:  ['1', '6']
# ------
# Chars:  ['2', '5', '.']
# Tokens:  ['2', '5', '.']
# ------
# Chars:  ['1', '6', '2', '5', '.']
# Tokens:  ['1', '6', '2', '5', '.']
# ------
# Chars:  ['d', 'i', 'e', 'ſ', 'e', 's']
# Tokens:  ['die', 'ſe', 's']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['K', 'i', 'r', 'c', 'h', 'e']
# Tokens:  ['K', 'ir', 'che']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['3', '1', '.']
# Tokens:  ['3', '1', '.']
# ------
# Chars:  ['d', 'i', 'e', 'ſ', 'e', 's']
# Tokens:  ['die', 'ſe', 's']
# ------
# Chars:  ['K', 'i', 'r', 'c', 'h', 'e']
# Tokens:  ['K', 'ir', 'che']
# ------
# Chars:  ['C', 'e', 'r', 'e', 'm', 'o', 'n', 'i', 'e', 'n']
# Tokens:  ['C', 'er', 'em', 'on', 'ie', 'n']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['C', 'hri', 'ſt', 'lic', 'hen']
# ------
# Chars:  ['b', 'e', 'ſ', 't', 'a', 't', '-']
# Tokens:  ['be', 'ſt', 'at', '-']
# ------
# Chars:  ['t', 'e', 't']
# Tokens:  ['te', 't']
# ------
# Chars:  ['w', 'o', 'r', 'd', 'e', 'n', ';']
# Tokens:  ['w', 'or', 'den', ';']
# ------
# Chars:  ['D', 'u', 'r', 'c', 'h']
# Tokens:  ['D', 'u', 'r', 'ch']
# ------
# Chars:  ['D', 'u', 'r', 'c', 'h']
# Tokens:  ['D', 'u', 'r', 'ch']
# ------
# Chars:  ['M', 'a', 'r', 't', 'i', 'n', 'u', 'm']
# Tokens:  ['M', 'ar', 'ti', 'n', 'u', 'm']
# ------
# Chars:  ['S', 'e', 'i', 'd', 'e', 'm', 'a', 'n', 'n', 'u', 'm']
# Tokens:  ['S', 'ei', 'de', 'm', 'an', 'n', 'u', 'm']
# ------
# Chars:  ['d', 'a', 'ſ', 'e', 'l', 'b', 'ſ', 't', '.']
# Tokens:  ['da', 'ſe', 'l', 'b', 'ſt', '.']
# ------
# Chars:  ['P', 'a', 'ſ', 't', 'o', 'r', 'e', 'm']
# Tokens:  ['P', 'a', 'ſt', 'or', 'em']
# ------
# Chars:  ['D', 'a', 's']
# Tokens:  ['D', 'a', 's']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'n']
# Tokens:  ['H', 'E', 'r', 'r', 'n']
# ------
# Chars:  ['D', 'a', 's']
# Tokens:  ['D', 'a', 's']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['V', 'a', 't', 'e', 'r']
# Tokens:  ['V', 'at', 'er']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['v', 'n', 's']
# Tokens:  ['vn', 's']
# ------
# Chars:  ['k', 'e', 'i', 't', '/']
# Tokens:  ['k', 'eit', '/']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['a', 'l', 'l', 'e', 's']
# Tokens:  ['all', 'es']
# ------
# Chars:  ['T', 'r', 'o', 'ſ', 't', 'e', 's', '/']
# Tokens:  ['T', 'r', 'o', 'ſte', 's', '/']
# ------
# Chars:  ['t', 'r', 'o', 'ͤ', 'ſ', 't', 'e', 't']
# Tokens:  ['t', 'r', 'o', 'ͤ', 'ſte', 't']
# ------
# Chars:  ['a', 'l', 'l', 'e', 'm']
# Tokens:  ['all', 'em']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r', 'm']
# Tokens:  ['vn', 'ſe', 'r', 'm']
# ------
# Chars:  ['d', 'a', 's']
# Tokens:  ['das']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['k', 'o', 'ͤ', 'n', 'n', 'e', 'n']
# Tokens:  ['k', 'o', 'ͤ', 'nn', 'en']
# ------
# Chars:  ['a', 'l', 'l', 'e', 'm']
# Tokens:  ['all', 'em']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r', 'm']
# Tokens:  ['vn', 'ſe', 'r', 'm']
# ------
# Chars:  ['T', 'r', 'u', 'ͤ', 'b', 'ſ', 'a', 'l', '/']
# Tokens:  ['T', 'r', 'uͤ', 'b', 'ſ', 'al', '/']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['k', 'o', 'ͤ', 'n', 'n', 'e', 'n']
# Tokens:  ['k', 'o', 'ͤ', 'nn', 'en']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['m', 'i', 't']
# Tokens:  ['mit']
# ------
# Chars:  ['t', 'r', 'o', 'ͤ', 'ſ', 't', 'e', 'n', '/']
# Tokens:  ['t', 'r', 'o', 'ͤ', 'ſte', 'n/']
# ------
# Chars:  ['d', 'a']
# Tokens:  ['da']
# ------
# Chars:  ['T', 'r', 'u', 'ͤ', 'b', 'ſ', 'a', 'l']
# Tokens:  ['T', 'r', 'uͤ', 'b', 'ſ', 'al']
# ------
# Chars:  ['H', 'o', 'c', 'h', 'g', 'e', 'l', 'o', 'b', 'e', 't']
# Tokens:  ['H', 'o', 'ch', 'ge', 'l', 'o', 'be', 't']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['d', 'e', 'n', '/']
# Tokens:  ['den', '/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['A', 'm', 'e', 'n', '.']
# Tokens:  ['A', 'me', 'n', '.']
# ------
# Chars:  ['A', 'm', 'e', 'n', '.']
# Tokens:  ['A', 'me', 'n', '.']
# ------
# Chars:  ['i', 'm']
# Tokens:  ['i', 'm']
# ------
# Chars:  ['G']
# Tokens:  ['G']
# ------
# Chars:  ['E', 'l', 'i', 'e', 'b', 't', 'e']
# Tokens:  ['E', 'li', 'eb', 'te']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['i', 'm']
# Tokens:  ['i', 'm']
# ------
# Chars:  ['H', 'E', 'R', 'R', 'N']
# Tokens:  ['H', 'E', 'R', 'R', 'N']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'o', '.']
# Tokens:  ['C', 'hri', 'ſt', 'o', '.']
# ------
# Chars:  ['A', 'm']
# Tokens:  ['A', 'm']
# ------
# Chars:  ['n', 'e', 'h', 'r', 'e', 'n']
# Tokens:  ['ne', 'hre', 'n']
# ------
# Chars:  ['S', 'o', 'n', 't', 'a', 'g']
# Tokens:  ['S', 'on', 't', 'a', 'g']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['g', 'e', 'h', 'o', 'ͤ', 'r', 'e', 't']
# Tokens:  ['ge', 'h', 'o', 'ͤ', 're', 't']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['b', 'e', 'r', 'u', 'f', 'f', 'e', 'n', 'e', 'n']
# Tokens:  ['ber', 'u', 'ff', 'en', 'en']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['b', 'e', 'r', 'u', 'f', 'f', 'e', 'n', 'e', 'n']
# Tokens:  ['ber', 'u', 'ff', 'en', 'en']
# ------
# Chars:  ['t', 'e', 'r', 'n']
# Tokens:  ['ter', 'n']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['M', 'e', 'i', 'n', 'b', 'e', 'r', 'g']
# Tokens:  ['M', 'ein', 'ber', 'g']
# ------
# Chars:  ['e', 'n', 'd', 'l', 'i', 'c', 'h']
# Tokens:  ['en', 'd', 'lic', 'h']
# ------
# Chars:  ['t', 'e', 'r', 'n']
# Tokens:  ['ter', 'n']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['G', 'c', 'h', 'a', 'f', 'f', 'n', 'e', 'r']
# Tokens:  ['G', 'ch', 'a', 'ff', 'ne', 'r']
# ------
# Chars:  ['S', 'c', 'h', 'a', 'f', 'f', 'n', 'e', 'r']
# Tokens:  ['S', 'ch', 'a', 'ff', 'ne', 'r']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e', 'n']
# Tokens:  ['li', 'ebe', 'n']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['B', 'e', 'l', 'o', 'h', 'n', 'u', 'n', 'g']
# Tokens:  ['B', 'el', 'o', 'h', 'n', 'un', 'g']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['B', 'e', 'l', 'o', 'h', 'n', 'u', 'n', 'g']
# Tokens:  ['B', 'el', 'o', 'h', 'n', 'un', 'g']
# ------
# Chars:  ['ſ', 'e', 'y', '.']
# Tokens:  ['ſe', 'y', '.']
# ------
# Chars:  ['J', 'n']
# Tokens:  ['J', 'n']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'n']
# Tokens:  ['H', 'E', 'r', 'r', 'n']
# ------
# Chars:  ['h', 'a', 't']
# Tokens:  ['ha', 't']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['n', 'u']
# Tokens:  ['n', 'u']
# ------
# Chars:  ['ſ', 'e', 'h', 'l', 'i', 'g', 'e']
# Tokens:  ['ſe', 'h', 'li', 'ge']
# ------
# Chars:  ['w', 'e', 'i', 'l', 'a', 'n', 'd']
# Tokens:  ['we', 'i', 'l', 'and']
# ------
# Chars:  ['E', 'r', 'b', 'a', 'r', 'e']
# Tokens:  ['E', 'r', 'b', 'ar', 'e']
# ------
# Chars:  ['v', 'i', 'e', 'l']
# Tokens:  ['v', 'ie', 'l']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['n', 'u']
# Tokens:  ['n', 'u']
# ------
# Chars:  ['m', 'e', 'h', 'r']
# Tokens:  ['me', 'hr']
# ------
# Chars:  ['ſ', 'e', 'h', 'l', 'i', 'g', 'e']
# Tokens:  ['ſe', 'h', 'li', 'ge']
# ------
# Chars:  ['w', 'e', 'i', 'l', 'a', 'n', 'd']
# Tokens:  ['we', 'i', 'l', 'and']
# ------
# Chars:  ['E', 'r', 'b', 'a', 'r', 'e']
# Tokens:  ['E', 'r', 'b', 'ar', 'e']
# ------
# Chars:  ['T', 'h', 'u', '-']
# Tokens:  ['T', 'h', 'u', '-']
# ------
# Chars:  ['g', 'e', 'n', 'd', 'r', 'e', 'i', 'c', 'h', 'e']
# Tokens:  ['gen', 'd', 're', 'ich', 'e']
# ------
# Chars:  ['B', 'a', 'r', 'b', 'a', 'r', 'a']
# Tokens:  ['B', 'ar', 'b', 'ar', 'a']
# ------
# Chars:  ['P', 'o', 't', 't', 'e', 'r', 'm', 'a', 'n', 'n', 'i', 'n']
# Tokens:  ['P', 'ott', 'er', 'm', 'an', 'ni', 'n']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['g', 'e', 'n', 'd', 'r', 'e', 'i', 'c', 'h', 'e']
# Tokens:  ['gen', 'd', 're', 'ich', 'e']
# ------
# Chars:  ['B', 'a', 'r', 'b', 'a', 'r', 'a']
# Tokens:  ['B', 'ar', 'b', 'ar', 'a']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['N', 'a', 'h', 'm', 'h', 'a', 'f', 'f', 't', 'e', 'n']
# Tokens:  ['N', 'a', 'h', 'm', 'ha', 'ff', 'ten']
# ------
# Chars:  ['H', 'e', 'r', 'r', 'n']
# Tokens:  ['H', 'er', 'r', 'n']
# ------
# Chars:  ['E', 'h', 'r', 'n', 'v', 'e', 'ſ', 't', 'e', 'n']
# Tokens:  ['E', 'hr', 'n', 'v', 'eſ', 'ten']
# ------
# Chars:  ['G', 'e', 'i', 'f', 'f', 'e', 'r', 't', 's']
# Tokens:  ['G', 'ei', 'ff', 'ert', 's']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['f', 'u', 'ͤ', 'r', 'n', 'e', 'h', 'm', 'e', 'n']
# Tokens:  ['f', 'uͤ', 'r', 'ne', 'h', 'me', 'n']
# ------
# Chars:  ['B', 'u', 'ͤ', 'r', 'g', 'e', 'r', 's']
# Tokens:  ['B', 'uͤ', 'r', 'ge', 'r', 's']
# ------
# Chars:  ['H', 'H', 'a', 'n', 'd', 'e', 'l', 'ß', '⸗']
# Tokens:  ['H', 'H', 'and', 'el', 'ß', '⸗']
# ------
# Chars:  ['f', 'u', 'ͤ', 'r', 'n', 'e', 'h', 'm', 'e', 'n']
# Tokens:  ['f', 'uͤ', 'r', 'ne', 'h', 'me', 'n']
# ------
# Chars:  ['B', 'u', 'ͤ', 'r', 'g', 'e', 'r', 's']
# Tokens:  ['B', 'uͤ', 'r', 'ge', 'r', 's']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['K', 'a', 'n', 'n', 'e', 's']
# Tokens:  ['K', 'an', 'ne', 's']
# ------
# Chars:  ['E', 'h', 'e', '⸗', 'E', 'r', 'a', 'w']
# Tokens:  ['E', 'he', '⸗', 'E', 'ra', 'w']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['M', 'a', 'n', 'n', 'e', 's']
# Tokens:  ['M', 'an', 'ne', 's']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['T', 'a', 'g', 'e', 's']
# Tokens:  ['T', 'a', 'ge', 's']
# ------
# Chars:  ['h', 'i', 't', 'z', 'e', '.']
# Tokens:  ['h', 'it', 'z', 'e', '.']
# ------
# Chars:  ['N', 'u', 'n']
# Tokens:  ['N', 'un']
# ------
# Chars:  ['m', 'u', 'ͤ', 'ſ', 'ſ', 'e', 'n']
# Tokens:  ['m', 'uͤ', 'ſſe', 'n']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['h', 'i', 't', 'z', 'e', '.']
# Tokens:  ['h', 'it', 'z', 'e', '.']
# ------
# Chars:  ['N', 'u', 'n']
# Tokens:  ['N', 'un']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['k', 'o', 'm', '̃', 'e', 'n']
# Tokens:  ['k', 'o', 'm', '̃', 'en']
# ------
# Chars:  ['l', 'a', 'n', 'g']
# Tokens:  ['l', 'an', 'g']
# ------
# Chars:  ['g', 'e', 'w', 'u', 'ͤ', 'n', 'ſ', 'c', 'h', 't', 'e']
# Tokens:  ['ge', 'w', 'uͤ', 'n', 'ſch', 'te']
# ------
# Chars:  ['F', 'e', 'y', '-']
# Tokens:  ['F', 'e', 'y', '-']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['J', 'h', 'r']
# Tokens:  ['J', 'hr']
# ------
# Chars:  ['t', 'r', 'u', 'ͤ', 'b', 'ſ', 'a', 'l']
# Tokens:  ['t', 'r', 'uͤ', 'b', 'ſ', 'al']
# ------
# Chars:  ['e', 'r', '-', 'A', 'b', 'e', 'n', 'd', '-', 'S', 't', 'u', 'ͤ', 'n', 'd', 'l', 'e', 'i', 'n', '/']
# Tokens:  ['er', '-', 'A', 'ben', 'd', '-', 'S', 't', 'uͤ', 'nd', 'lei', 'n/']
# ------
# Chars:  ['t', 'r', 'u', 'ͤ', 'b', 'ſ', 'a', 'l']
# Tokens:  ['t', 'r', 'uͤ', 'b', 'ſ', 'al']
# ------
# Chars:  ['ſ', 'c', 'h', 'a', 'f', 'f', 't']
# Tokens:  ['ſch', 'a', 'ff', 't']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['z', 'u']
# Tokens:  ['zu']
# ------
# Chars:  ['h', 'e', 'r', 't', 'z', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['her', 'tz', 'lic', 'hen']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'c', 'h', 'm', 'e', 'r', 't', 'z', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['ſch', 'me', 'rt', 'z', 'lic', 'hen']
# ------
# Chars:  ['L', 'e', 'i', 'd']
# Tokens:  ['L', 'ei', 'd']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['w', 'e', 'n', 'd', 'e', 'n']
# Tokens:  ['we', 'nde', 'n']
# ------
# Chars:  ['w', 'o', 'l', 'l', 'e', 'n']
# Tokens:  ['w', 'o', 'lle', 'n']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['v', 'n', 's']
# Tokens:  ['vn', 's']
# ------
# Chars:  ['b', 'e', 't', 'r', 'a', 'c', 'h', 't', 'u', 'n', 'g']
# Tokens:  ['be', 't', 'ra', 'cht', 'un', 'g']
# ------
# Chars:  ['w', 'e', 'l', 'c', 'h', 'e', 's']
# Tokens:  ['we', 'l', 'che', 's']
# ------
# Chars:  ['i', 'ſ', 't']
# Tokens:  ['iſt']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['G', 'o', 'ͤ', 't', 't', 'l', 'i', 'c', 'h', 'e', 's']
# Tokens:  ['G', 'o', 'ͤ', 'tt', 'lic', 'he', 's']
# ------
# Chars:  ['W', 'o', 'r', 't', 's', '/']
# Tokens:  ['W', 'or', 't', 's', '/']
# ------
# Chars:  ['i', 'ſ', 't']
# Tokens:  ['iſt']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['a', 'l', 'l', 'e', 's']
# Tokens:  ['all', 'es']
# ------
# Chars:  ['k', 'r', 'a', 'ͤ', 'f', 'f', 't', 'i', 'g', 'e', 'n']
# Tokens:  ['k', 'ra', 'ͤ', 'ff', 'ti', 'gen']
# ------
# Chars:  ['G', 'e', 'r', 't', 'z', '⸗', 'e', 'r', 'q', 'u', 'i', 'c', 'k', 'e', 'n', '⸗']
# Tokens:  ['G', 'ert', 'z', '⸗', 'er', 'q', 'u', 'ic', 'k', 'en', '⸗']
# ------
# Chars:  ['B', 'r', 'u', 'n', 'n', 'q', 'u', 'e', 'l', 'l']
# Tokens:  ['B', 'r', 'un', 'n', 'q', 'u', 'el', 'l']
# ------
# Chars:  ['a', 'l', 'l', 'e', 's']
# Tokens:  ['all', 'es']
# ------
# Chars:  ['k', 'r', 'a', 'ͤ', 'f', 'f', 't', 'i', 'g', 'e', 'n']
# Tokens:  ['k', 'ra', 'ͤ', 'ff', 'ti', 'gen']
# ------
# Chars:  ['H', 'e', 'r', 't', 'z', '-', 'e', 'r', 'q', 'u', 'i', 'c', 'k', 'e', 'n', '-']
# Tokens:  ['H', 'ert', 'z', '-', 'er', 'q', 'u', 'ic', 'k', 'en', '-']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'a', 'ſ', 'ſ', 'e', 'l', 'b', 'e']
# Tokens:  ['da', 'ſſe', 'l', 'be']
# ------
# Chars:  ['V', 'n', 'd']
# Tokens:  ['V', 'nd']
# ------
# Chars:  ['d', 'a', 'm', 'i', 't']
# Tokens:  ['da', 'mit']
# ------
# Chars:  ['n', 'u', 'ͤ', 't', 'z', '-']
# Tokens:  ['n', 'uͤ', 'tz', '-']
# ------
# Chars:  ['g', 'e', 'l', 'e', 'h', 'r', 'e', 't']
# Tokens:  ['ge', 'le', 'hre', 't']
# ------
# Chars:  ['w', 'e', 'r', 'd', 'e']
# Tokens:  ['we', 'r', 'de']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['g', 'e', 'l', 'e', 'h', 'r', 'e', 't']
# Tokens:  ['ge', 'le', 'hre', 't']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['a', 'n', 'g', 'e', 'h', 'o', 'ͤ', 'r', 'e', 't']
# Tokens:  ['an', 'ge', 'h', 'o', 'ͤ', 're', 't']
# ------
# Chars:  ['w', 'e', 'r', 'd', 'e', '/']
# Tokens:  ['we', 'r', 'de', '/']
# ------
# Chars:  ['W', 'o', 'l', 'l', 'e', 'n']
# Tokens:  ['W', 'o', 'lle', 'n']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['d', 'e', 'm', 'u', 'ͤ', 't', 'i', 'g', 'e', 'n']
# Tokens:  ['de', 'm', 'uͤ', 'ti', 'gen']
# ------
# Chars:  ['g', 'l', 'a', 'ͤ', 'u', '⸗']
# Tokens:  ['g', 'l', 'a', 'ͤ', 'u', '⸗']
# ------
# Chars:  ['v', 'n', 's']
# Tokens:  ['vn', 's']
# ------
# Chars:  ['f', 'u', 'ͤ', 'r']
# Tokens:  ['f', 'uͤ', 'r']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['d', 'e', 'm', 'u', 'ͤ', 't', 'i', 'g', 'e', 'n', '/']
# Tokens:  ['de', 'm', 'uͤ', 'ti', 'gen', '/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['b', 'i', 'g', 'e', 's']
# Tokens:  ['b', 'ige', 's']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r']
# Tokens:  ['vn', 'ſe', 'r']
# ------
# Chars:  ['b', 'i', 'g', 'e', 's']
# Tokens:  ['b', 'ige', 's']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r', '/']
# Tokens:  ['vn', 'ſe', 'r', '/']
# ------
# Chars:  ['ꝛ', 'c', '.']
# Tokens:  ['ꝛ', 'c', '.']
# ------
# Chars:  ['W', 'o']
# Tokens:  ['W', 'o']
# ------
# Chars:  ['d', 'e', 'i', 'n']
# Tokens:  ['de', 'in']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['m', 'e', 'i', 'n']
# Tokens:  ['me', 'in']
# ------
# Chars:  ['T', 'r', 'o', 'ſ', 't']
# Tokens:  ['T', 'r', 'o', 'ſt']
# ------
# Chars:  ['g', 'e', '⸗']
# Tokens:  ['ge', '⸗']
# ------
# Chars:  ['m', 'e', 'i', 'n']
# Tokens:  ['me', 'in']
# ------
# Chars:  ['w', 'e', 'ſ', 't']
# Tokens:  ['we', 'ſt']
# ------
# Chars:  ['w', 'e', 'r', 'e']
# Tokens:  ['we', 're']
# ------
# Chars:  ['S', 'o']
# Tokens:  ['S', 'o']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['v', 'e', 'r', 'g', 'a', 'n', 'g', 'e', 'n']
# Tokens:  ['ver', 'g', 'an', 'gen']
# ------
# Chars:  ['w', 'e', 'r', 'e', '/']
# Tokens:  ['we', 're', '/']
# ------
# Chars:  ['w', 'e', 'r', 'e']
# Tokens:  ['we', 're']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['v', 'e', 'r', 'g', 'a', 'n', 'g', 'e', 'n']
# Tokens:  ['ver', 'g', 'an', 'gen']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['E', 'l', 'e', 'n', 'd', '.']
# Tokens:  ['E', 'len', 'd', '.']
# ------
# Chars:  ['J', 'c', 'h']
# Tokens:  ['J', 'ch']
# ------
# Chars:  ['w', 'i', 'l']
# Tokens:  ['wi', 'l']
# ------
# Chars:  ['n', 'i', 'm', 'm', 'e', 'r', 'm', 'e', 'h', 'r']
# Tokens:  ['ni', 'm', 'me', 'r', 'me', 'hr']
# ------
# Chars:  ['v', 'e', 'r', 'g', 'e', 'ſ', 'ſ', 'e', 'n']
# Tokens:  ['ver', 'ge', 'ſſe', 'n']
# ------
# Chars:  ['D', 'e', 'ñ']
# Tokens:  ['D', 'e', 'ñ']
# ------
# Chars:  ['d', 'u']
# Tokens:  ['d', 'u']
# ------
# Chars:  ['v', 'e', 'r', 'g', 'e', 'ſ', 'ſ', 'e', 'n', '/']
# Tokens:  ['ver', 'ge', 'ſſe', 'n/']
# ------
# Chars:  ['d', 'u']
# Tokens:  ['d', 'u']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['v', 'n', 't', 'e', 'r']
# Tokens:  ['vn', 'ter']
# ------
# Chars:  ['d', 'e', 'm']
# Tokens:  ['de', 'm']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z']
# Tokens:  ['C', 're', 'u', 'tz']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'n']
# Tokens:  ['H', 'E', 'r', 'r', 'n']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['d', 'e', 'm']
# Tokens:  ['de', 'm']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z']
# Tokens:  ['C', 're', 'u', 'tz']
# ------
# Chars:  ['d', 'e', 's']
# Tokens:  ['de', 's']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'n']
# Tokens:  ['H', 'E', 'r', 'r', 'n']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['d', 'e', 'ſ', 'ſ', 'e', 'l', 'b', 'e', 'n']
# Tokens:  ['de', 'ſſe', 'l', 'ben']
# ------
# Chars:  ['m', 'u', 'ͤ', 'ſ', 'ſ', 'e', 'n', '.']
# Tokens:  ['m', 'uͤ', 'ſſe', 'n', '.']
# ------
# Chars:  ['ſ', 't', 'e', 'h', 'e', 'n', '/']
# Tokens:  ['ſte', 'hen', '/']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['g', 'u', 't']
# Tokens:  ['g', 'u', 't']
# ------
# Chars:  ['t', 'h', 'e', 'i', 'l']
# Tokens:  ['t', 'he', 'i', 'l']
# ------
# Chars:  ['d', 'e', 'ſ', 'ſ', 'e', 'l', 'b', 'e', 'n']
# Tokens:  ['de', 'ſſe', 'l', 'ben']
# ------
# Chars:  ['t', 'r', 'a', 'g', 'e', 'n']
# Tokens:  ['t', 'ra', 'gen']
# ------
# Chars:  ['g', 'l', 'e', 'i', 'c', 'h']
# Tokens:  ['g', 'lei', 'ch']
# ------
# Chars:  ['b', 'i', 'ß', 'w', 'e', 'i', 'l', 'e', 'n']
# Tokens:  ['b', 'i', 'ß', 'we', 'i', 'len']
# ------
# Chars:  ['V', 'n', 'g', 'e', 'd', 'u', 'l', 't']
# Tokens:  ['V', 'ng', 'e', 'd', 'u', 'l', 't']
# ------
# Chars:  ['g', 'e', 'w', 'i', 't', '⸗']
# Tokens:  ['ge', 'wi', 't', '⸗']
# ------
# Chars:  ['V', 'n', 'd']
# Tokens:  ['V', 'nd']
# ------
# Chars:  ['b', 'i', 'ß', 'w', 'e', 'i', 'l', 'e', 'n']
# Tokens:  ['b', 'i', 'ß', 'we', 'i', 'len']
# ------
# Chars:  ['V', 'n', 'g', 'e', 'd', 'u', 'l', 't']
# Tokens:  ['V', 'ng', 'e', 'd', 'u', 'l', 't']
# ------
# Chars:  ['ſ', 'i', 'c', 'h']
# Tokens:  ['ſi', 'ch']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['h', 'a', 't']
# Tokens:  ['ha', 't']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['l', 'a', 'ſ', 'ſ', 'e', 'n']
# Tokens:  ['l', 'a', 'ſſe', 'n']
# ------
# Chars:  ['ſ', 'o', 'n', 'd', 'e', 'r', 'n']
# Tokens:  ['ſo', 'nde', 'r', 'n']
# ------
# Chars:  ['ſ', 'i', 'c', 'h']
# Tokens:  ['ſi', 'ch']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', 'e', 'm']
# Tokens:  ['ſei', 'ne', 'm']
# ------
# Chars:  ['m', 'i', 't']
# Tokens:  ['mit']
# ------
# Chars:  ['g', 'l', 'a', 'u', 'b', 'e', 'n']
# Tokens:  ['g', 'l', 'au', 'ben']
# ------
# Chars:  ['e', 'r', 'g', 'r', 'i', 'f', 'f', 'e', 'n']
# Tokens:  ['er', 'g', 'ri', 'ff', 'en']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', 'e', 'm']
# Tokens:  ['ſei', 'ne', 'm']
# ------
# Chars:  ['W', 'o', 'r', 't']
# Tokens:  ['W', 'or', 't']
# ------
# Chars:  ['m', 'i', 't']
# Tokens:  ['mit']
# ------
# Chars:  ['w', 'a', 'r', 'h', 'a', 'f', 'f', 't', 'i', 'g', 'e', 'm']
# Tokens:  ['w', 'ar', 'ha', 'ff', 'ti', 'ge', 'm']
# ------
# Chars:  ['g', 'l', 'a', 'u', 'b', 'e', 'n']
# Tokens:  ['g', 'l', 'au', 'ben']
# ------
# Chars:  ['e', 'r', 'g', 'r', 'i', 'f', 'f', 'e', 'n', '/']
# Tokens:  ['er', 'g', 'ri', 'ff', 'en/']
# ------
# Chars:  ['ſ', 'i', 'c', 'h']
# Tokens:  ['ſi', 'ch']
# ------
# Chars:  ['e', 'i', 'n', 'e']
# Tokens:  ['ein', 'e']
# ------
# Chars:  ['r', 'e', 'c', 'h', 't', 'e']
# Tokens:  ['re', 'cht', 'e']
# ------
# Chars:  ['S', 'u', 'ͤ', 'n', 'd', 'e', 'r', 'i', 'n']
# Tokens:  ['S', 'uͤ', 'nde', 'ri', 'n']
# ------
# Chars:  ['a', 'l', 's']
# Tokens:  ['al', 's']
# ------
# Chars:  ['e', 'i', 'n', 'e']
# Tokens:  ['ein', 'e']
# ------
# Chars:  ['r', 'e', 'c', 'h', 't', 'e']
# Tokens:  ['re', 'cht', 'e']
# ------
# Chars:  ['e', 'r', 'z', 'e', 'i', 'g', 'e', 't', '.']
# Tokens:  ['er', 'z', 'ei', 'ge', 't', '.']
# ------
# Chars:  ['V', 'ñ']
# Tokens:  ['V', 'ñ']
# ------
# Chars:  ['j', 'h', 'r']
# Tokens:  ['j', 'hr']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['j', 'e']
# Tokens:  ['j', 'e']
# ------
# Chars:  ['m', 'e', 'h', 'r']
# Tokens:  ['me', 'hr']
# ------
# Chars:  ['j', 'e']
# Tokens:  ['j', 'e']
# ------
# Chars:  ['m', 'e', 'h', 'r']
# Tokens:  ['me', 'hr']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['j', 'e']
# Tokens:  ['j', 'e']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['d', 'e', 'm', 'ſ', 'e', 'l', 'b', 'e', 'n']
# Tokens:  ['de', 'm', 'ſe', 'l', 'ben']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z']
# Tokens:  ['C', 're', 'u', 'tz']
# ------
# Chars:  ['g', 'e', 'l', 'i', 'e', 'b', 'e', 't', '/']
# Tokens:  ['ge', 'li', 'ebe', 't/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['j', 'h', 'r']
# Tokens:  ['j', 'hr']
# ------
# Chars:  ['d', 'u', 'l', 'd', 'i', 'g']
# Tokens:  ['d', 'u', 'l', 'di', 'g']
# ------
# Chars:  ['n', 'a', 'c', 'h', 'g', 'e', 't', 'r', 'a', 'g', 'ẽ']
# Tokens:  ['n', 'ach', 'ge', 't', 'ra', 'g', 'ẽ']
# ------
# Chars:  ['D', 'a', 'r', 'u', 'm', 'b']
# Tokens:  ['D', 'ar', 'u', 'm', 'b']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['z', 'u']
# Tokens:  ['zu']
# ------
# Chars:  ['j', 'h', 'r', 'e', 'm']
# Tokens:  ['j', 'hre', 'm']
# ------
# Chars:  ['d', 'u', 'l', 'd', 'i', 'g']
# Tokens:  ['d', 'u', 'l', 'di', 'g']
# ------
# Chars:  ['n', 'a', 'c', 'h', 'g', 'e', 't', 'r', 'a', 'g', 'ẽ', '/']
# Tokens:  ['n', 'ach', 'ge', 't', 'ra', 'g', 'ẽ', '/']
# ------
# Chars:  ['D', 'a', 'r', 'u', 'm', 'b']
# Tokens:  ['D', 'ar', 'u', 'm', 'b']
# ------
# Chars:  ['z', 'u']
# Tokens:  ['zu']
# ------
# Chars:  ['L', 'e', 'i', 'c', 'h', '-']
# Tokens:  ['L', 'ei', 'ch', '-']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['S', 'p', 'r', 'u', 'c', 'h']
# Tokens:  ['S', 'p', 'r', 'uch']
# ------
# Chars:  ['1', '1', '9', '.']
# Tokens:  ['1', '1', '9', '.']
# ------
# Chars:  ['P', 'ſ', 'a', 'l']
# Tokens:  ['P', 'ſ', 'al']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['a', 'b', 'g', 'e', 'l', 'e', 'ſ', 'e', 'n', 'e']
# Tokens:  ['a', 'b', 'ge', 'le', 'ſen', 'e']
# ------
# Chars:  ['a', 'u', 's']
# Tokens:  ['au', 's']
# ------
# Chars:  ['1', '1', '9', '.']
# Tokens:  ['1', '1', '9', '.']
# ------
# Chars:  ['P', 'ſ', 'a', 'l', '.']
# Tokens:  ['P', 'ſ', 'al', '.']
# ------
# Chars:  ['h', 'a', 'n', 'd', 'e', 'l', 'n']
# Tokens:  ['ha', 'nde', 'l', 'n']
# ------
# Chars:  ['2', '.']
# Tokens:  ['2', '.']
# ------
# Chars:  ['S', 't', 'u', 'ͤ', 'c', 'k', 'e', ':']
# Tokens:  ['S', 't', 'uͤ', 'c', 'k', 'e', ':']
# ------
# Chars:  ['h', 'a', 'n', 'd', 'e', 'l', 'n']
# Tokens:  ['ha', 'nde', 'l', 'n']
# ------
# Chars:  ['2', '.']
# Tokens:  ['2', '.']
# ------
# Chars:  ['S', 't', 'u', 'ͤ', 'c', 'k', 'e', ':']
# Tokens:  ['S', 't', 'uͤ', 'c', 'k', 'e', ':']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'ʒ', 't', 'r', 'a', 'ͤ', 'g', 'e', 'r', 'n']
# Tokens:  ['C', 're', 'u', 't', 'ʒ', 't', 'ra', 'ͤ', 'ge', 'r', 'n']
# ------
# Chars:  ['W', 'e', 'l', 'c', 'h', 'e', 's']
# Tokens:  ['W', 'el', 'che', 's']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['C', 'hri', 'ſt', 'lic', 'hen']
# ------
# Chars:  ['e', 'i', 'n', 'i', '-']
# Tokens:  ['ein', 'i', '-']
# ------
# Chars:  ['l', 'a', 'b', 'ſ', 'a', 'l', 'l']
# Tokens:  ['l', 'a', 'b', 'ſ', 'all']
# ------
# Chars:  ['e', 'r', 'q', 'u', 'i', 'c', 'k', 'u', 'n', 'g']
# Tokens:  ['er', 'q', 'u', 'ic', 'k', 'un', 'g']
# ------
# Chars:  ['ſ', 'e', 'y', '.']
# Tokens:  ['ſe', 'y', '.']
# ------
# Chars:  ['g', 'e', 'r']
# Tokens:  ['ge', 'r']
# ------
# Chars:  ['t', 'r', 'o', 'ſ', 't', '/']
# Tokens:  ['t', 'r', 'o', 'ſt', '/']
# ------
# Chars:  ['l', 'a', 'b', 'ſ', 'a', 'l', 'l']
# Tokens:  ['l', 'a', 'b', 'ſ', 'all']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'e', 'y', '.']
# Tokens:  ['ſe', 'y', '.']
# ------
# Chars:  ['I', 'I', '.']
# Tokens:  ['I', 'I', '.']
# ------
# Chars:  ['W', 'i', 'e']
# Tokens:  ['W', 'ie']
# ------
# Chars:  ['g', 'e', 'g', 'e', 'n']
# Tokens:  ['ge', 'gen']
# ------
# Chars:  ['d', 'e', 'm', 'ſ', 'e', 'l', 'b', 'e', 'n']
# Tokens:  ['de', 'm', 'ſe', 'l', 'ben']
# ------
# Chars:  ['d', 'e', 'm', 'ſ', 'e', 'l', 'b', 'e', 'n']
# Tokens:  ['de', 'm', 'ſe', 'l', 'ben']
# ------
# Chars:  ['v', 'e', 'r', 'h', 'a', 'l', 't', 'e', 'n']
# Tokens:  ['ver', 'ha', 'l', 'ten']
# ------
# Chars:  ['D', 'e', 'r']
# Tokens:  ['D', 'er']
# ------
# Chars:  ['H', 'E', 'r', 'r']
# Tokens:  ['H', 'E', 'r', 'r']
# ------
# Chars:  ['J', 'e', 'ſ', 'u', 's']
# Tokens:  ['J', 'eſ', 'u', 's']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'u', 's']
# Tokens:  ['C', 'hri', 'ſt', 'u', 's']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['V', 'o', 'r', 'g', 'a', 'ͤ', 'n', 'g', 'e', 'r']
# Tokens:  ['V', 'or', 'g', 'a', 'ͤ', 'ng', 'er']
# ------
# Chars:  ['a', 'l', '⸗']
# Tokens:  ['al', '⸗']
# ------
# Chars:  ['D', 'e', 'r']
# Tokens:  ['D', 'er']
# ------
# Chars:  ['H', 'E', 'r', 'r']
# Tokens:  ['H', 'E', 'r', 'r']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't', 'u', 's', '/']
# Tokens:  ['C', 'hri', 'ſt', 'u', 's', '/']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['V', 'o', 'r', 'g', 'a', 'ͤ', 'n', 'g', 'e', 'r']
# Tokens:  ['V', 'or', 'g', 'a', 'ͤ', 'ng', 'er']
# ------
# Chars:  ['l', 'e', 'r']
# Tokens:  ['le', 'r']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'e', 'i', 'h', 'e']
# Tokens:  ['ver', 'lei', 'he']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z', 't', 'r', 'a', 'ͤ', 'g', 'e', 'r', '/']
# Tokens:  ['C', 're', 'u', 'tz', 't', 'ra', 'ͤ', 'ge', 'r', '/']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'e', 'i', 'h', 'e']
# Tokens:  ['ver', 'lei', 'he']
# ------
# Chars:  ['d', 'a', 'z', 'u']
# Tokens:  ['da', 'zu']
# ------
# Chars:  ['G', 'n', 'a', 'd']
# Tokens:  ['G', 'n', 'a', 'd']
# ------
# Chars:  ['D', 'e']
# Tokens:  ['D', 'e']
# ------
# Chars:  ['m', 'u', 'ͤ', 'ſ', 'ſ', 'e', 'n']
# Tokens:  ['m', 'uͤ', 'ſſe', 'n']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z', 't', 'r', 'a', 'ͤ', 'g', 'e', 'r']
# Tokens:  ['C', 're', 'u', 'tz', 't', 'ra', 'ͤ', 'ge', 'r']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z', 't', 'r', 'a', 'ͤ', 'g', 'e', 'r']
# Tokens:  ['C', 're', 'u', 'tz', 't', 'ra', 'ͤ', 'ge', 'r']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['i', 'ſ', 't']
# Tokens:  ['iſt']
# ------
# Chars:  ['a', 'u', 'ſ', 'ſ', 'e', 'r']
# Tokens:  ['au', 'ſſe', 'r']
# ------
# Chars:  ['Q', 'u', 'i']
# Tokens:  ['Q', 'u', 'i']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', '/']
# Tokens:  ['ſei', 'n/']
# ------
# Chars:  ['z', 'w', 'e', 'i', 'f', 'f', 'e', 'l', '.']
# Tokens:  ['z', 'we', 'i', 'ff', 'el', '.']
# ------
# Chars:  ['Q', 'u', 'i']
# Tokens:  ['Q', 'u', 'i']
# ------
# Chars:  ['e', 'ſ', 'ſ', 'e']
# Tokens:  ['eſ', 'ſe']
# ------
# Chars:  ['ſ', 'i', 't']
# Tokens:  ['ſi', 't']
# ------
# Chars:  ['C', 'r', 'u', 'c', 'i', 'a', 'n', 'u', 's']
# Tokens:  ['C', 'r', 'u', 'c', 'i', 'an', 'u', 's']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'i', 't']
# Tokens:  ['ſi', 't']
# ------
# Chars:  ['C', 'r', 'u', 'c', 'i', 'a', 'n', 'u', 's', '/']
# Tokens:  ['C', 'r', 'u', 'c', 'i', 'an', 'u', 's', '/']
# ------
# Chars:  ['D', '.']
# Tokens:  ['D', '.']
# ------
# Chars:  ['z', 'u']
# Tokens:  ['zu']
# ------
# Chars:  ['W', 'e', 'r']
# Tokens:  ['W', 'er']
# ------
# Chars:  ['L', 'u', 't', 'h', 'e', 'r', 'u', 's']
# Tokens:  ['L', 'u', 't', 'her', 'u', 's']
# ------
# Chars:  ['p', 'f', 'l', 'e', 'g', 'e', 'n']
# Tokens:  ['p', 'f', 'le', 'gen']
# ------
# Chars:  ['ſ', 'a', 'g', 'e', 'n', '/']
# Tokens:  ['ſ', 'a', 'gen', '/']
# ------
# Chars:  ['W', 'e', 'r']
# Tokens:  ['W', 'er']
# ------
# Chars:  ['C', 'h', 'r', 'i', 'ſ', 't']
# Tokens:  ['C', 'hri', 'ſt']
# ------
# Chars:  ['w', 'i', 'l']
# Tokens:  ['wi', 'l']
# ------
# Chars:  ['d', 'e', 'r', 'ſ', 'e', 'l', 'b', 'e']
# Tokens:  ['der', 'ſe', 'l', 'be']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z', 't', 'r', 'a', 'g', 'e', 'r']
# Tokens:  ['C', 're', 'u', 'tz', 't', 'ra', 'ge', 'r']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'e', 'r', 'ſ', 'e', 'l', 'b', 'e']
# Tokens:  ['der', 'ſe', 'l', 'be']
# ------
# Chars:  ['m', 'u', 'ß']
# Tokens:  ['m', 'u', 'ß']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', '/']
# Tokens:  ['ſei', 'n/']
# ------
# Chars:  ['b', 'e', 'z', 'e', 'u', 'g', 'e', 't']
# Tokens:  ['be', 'z', 'e', 'u', 'ge', 't']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['S', 'y', 'r', 'a', 'c', 'h']
# Tokens:  ['S', 'y', 'ra', 'ch']
# ------
# Chars:  ['c', '.']
# Tokens:  ['c', '.']
# ------
# Chars:  ['2', '.']
# Tokens:  ['2', '.']
# ------
# Chars:  ['D', 'e', 'n', 'n']
# Tokens:  ['D', 'enn']
# ------
# Chars:  ['b', 'e', 'z', 'e', 'u', 'g', 'e', 't']
# Tokens:  ['be', 'z', 'e', 'u', 'ge', 't']
# ------
# Chars:  ['c', '.']
# Tokens:  ['c', '.']
# ------
# Chars:  ['K', 'i', 'n', 'd']
# Tokens:  ['K', 'in', 'd']
# ------
# Chars:  ['w', 'i', 'l', 't']
# Tokens:  ['wi', 'l', 't']
# ------
# Chars:  ['ſ', 'e', 'i', 'n']
# Tokens:  ['ſei', 'n']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'o']
# Tokens:  ['ſo']
# ------
# Chars:  ['M', 'e', 'i', 'n']
# Tokens:  ['M', 'ein']
# ------
# Chars:  ['w', 'i', 'l', 't']
# Tokens:  ['wi', 'l', 't']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', '/']
# Tokens:  ['ſei', 'n/']
# ------
# Chars:  ['ſ', 'c', 'h', 'i', '-']
# Tokens:  ['ſch', 'i', '-']
# ------
# Chars:  ['c', 'k', 'e']
# Tokens:  ['c', 'k', 'e']
# ------
# Chars:  ['d', 'i', 'c', 'h']
# Tokens:  ['di', 'ch']
# ------
# Chars:  ['z', 'u', 'r']
# Tokens:  ['zu', 'r']
# ------
# Chars:  ['a', 'n', 'f', 'e', 'c', 'h', 't', 'u', 'n', 'g', '.']
# Tokens:  ['an', 'f', 'e', 'cht', 'un', 'g', '.']
# ------
# Chars:  ['1', '6']
# Tokens:  ['1', '6']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['c', 'k', 'e']
# Tokens:  ['c', 'k', 'e']
# ------
# Chars:  ['d', 'i', 'c', 'h']
# Tokens:  ['di', 'ch']
# ------
# Chars:  ['z', 'u', 'r']
# Tokens:  ['zu', 'r']
# ------
# Chars:  ['a', 'n', 'f', 'e', 'c', 'h', 't', 'u', 'n', 'g', '.']
# Tokens:  ['an', 'f', 'e', 'cht', 'un', 'g', '.']
# ------
# Chars:  ['M', 'a', 't', 't', 'h', '.']
# Tokens:  ['M', 'at', 't', 'h', '.']
# ------
# Chars:  ['1', '6']
# Tokens:  ['1', '6']
# ------
# Chars:  ['ſ', 'p', 'r', 'i', 'c', 'h', 't']
# Tokens:  ['ſ', 'p', 'ri', 'cht']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['n', 'e', 'h', 'm', 'e']
# Tokens:  ['ne', 'h', 'me']
# ------
# Chars:  ['a', 'b', 'e', 'r']
# Tokens:  ['abe', 'r']
# ------
# Chars:  ['ſ', 'e', 'i', 'n']
# Tokens:  ['ſei', 'n']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'e', 'u', 'g', 'n', 'e']
# Tokens:  ['ver', 'le', 'u', 'g', 'ne']
# ------
# Chars:  ['ſ', 'e', 'l', 'b', 'ſ', 't', '/']
# Tokens:  ['ſe', 'l', 'b', 'ſt', '/']
# ------
# Chars:  ['a', 'b', 'e', 'r']
# Tokens:  ['abe', 'r']
# ------
# Chars:  ['a', 'u', 'f', 'f']
# Tokens:  ['au', 'ff']
# ------
# Chars:  ['m', 'i', 'r']
# Tokens:  ['mi', 'r']
# ------
# Chars:  ['n', 'a', 'c', 'h', '.']
# Tokens:  ['n', 'ach', '.']
# ------
# Chars:  ['Z', 'u', 'n']
# Tokens:  ['Z', 'un']
# ------
# Chars:  ['C', 'r', 'e', 'u', 't', 'z']
# Tokens:  ['C', 're', 'u', 'tz']
# ------
# Chars:  ['a', 'u', 'f', 'f']
# Tokens:  ['au', 'ff']
# ------
# Chars:  ['H', 'e', 'b', 'r', '.']
# Tokens:  ['H', 'eb', 'r', '.']
# ------
# Chars:  ['G', 'o', 'h', 'n']
# Tokens:  ['G', 'o', 'h', 'n']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['z', 'u', 'ͤ', 'c', 'h', '⸗']
# Tokens:  ['zu', 'ͤ', 'ch', '⸗']
# ------
# Chars:  ['1', '2', ':']
# Tokens:  ['1', '2', ':']
# ------
# Chars:  ['a', 'c', 'h', 't', 'e']
# Tokens:  ['ach', 'te']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['z', 'u', 'ͤ', 'c', 'h', '-']
# Tokens:  ['zu', 'ͤ', 'ch', '-']
# ------
# Chars:  ['h', 'a', 't']
# Tokens:  ['ha', 't']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['a', 'b', 'e', 'r']
# Tokens:  ['abe', 'r']
# ------
# Chars:  ['e', 'i', 'n', 'e', 'n']
# Tokens:  ['ein', 'en']
# ------
# Chars:  ['z', 'u', 'ͤ', 'c', 'h', 't', 'i', 'g', 'e', 't']
# Tokens:  ['zu', 'ͤ', 'cht', 'ige', 't']
# ------
# Chars:  ['e', 'r', '/']
# Tokens:  ['er', '/']
# ------
# Chars:  ['E', 'r']
# Tokens:  ['E', 'r']
# ------
# Chars:  ['j', 'e', 'g', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['j', 'e', 'g', 'lic', 'hen']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['e', 'r']
# Tokens:  ['er']
# ------
# Chars:  ['a', 'u', 'f', 'f', 'n', 'i', 'm', '̃', 't']
# Tokens:  ['au', 'ff', 'ni', 'm', '̃', 't']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['z', 'u', 'ͤ', 'c', 'h', '⸗']
# Tokens:  ['zu', 'ͤ', 'ch', '⸗']
# ------
# Chars:  ['j', 'e', 'g', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['j', 'e', 'g', 'lic', 'hen']
# ------
# Chars:  ['S', 'o', 'h', 'n', '/']
# Tokens:  ['S', 'o', 'h', 'n/']
# ------
# Chars:  ['t', 'i', 'g', 'u', 'n', 'g']
# Tokens:  ['ti', 'g', 'un', 'g']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'o']
# Tokens:  ['ſo']
# ------
# Chars:  ['e', 'r', 'b', 'e', 'u', 't']
# Tokens:  ['er', 'be', 'u', 't']
# ------
# Chars:  ['e', 'r']
# Tokens:  ['er']
# ------
# Chars:  ['ſ', 't', 'c', 'h']
# Tokens:  ['ſt', 'ch']
# ------
# Chars:  ['e', 'u', 'c', 'h']
# Tokens:  ['e', 'uch']
# ------
# Chars:  ['a', 'l', 's']
# Tokens:  ['al', 's']
# ------
# Chars:  ['t', 'i', 'g', 'u', 'n', 'g']
# Tokens:  ['ti', 'g', 'un', 'g']
# ------
# Chars:  ['ſ', 'o']
# Tokens:  ['ſo']
# ------
# Chars:  ['e', 'r', 'b', 'e', 'u', 't']
# Tokens:  ['er', 'be', 'u', 't']
# ------
# Chars:  ['K', 'i', 'n', '-']
# Tokens:  ['K', 'in', '-']
# ------
# Chars:  ['d', 'e', 'r', 'n']
# Tokens:  ['der', 'n']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['V', 'a', 't', 'e', 'r']
# Tokens:  ['V', 'at', 'er']
# ------
# Chars:  ['D', 'e', 'n', 'n']
# Tokens:  ['D', 'enn']
# ------
# Chars:  ['i', 'ſ', 't']
# Tokens:  ['iſt']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'e', 'i', 'd']
# Tokens:  ['ſei', 'd']
# ------
# Chars:  ['J', 'h', 'r']
# Tokens:  ['J', 'hr']
# ------
# Chars:  ['a', 'b', 'e', 'r']
# Tokens:  ['abe', 'r']
# ------
# Chars:  ['z', 'u', 'ͤ', 'c', 'h', 't', 'i', 'g', 'e', 't', '/']
# Tokens:  ['zu', 'ͤ', 'cht', 'ige', 't/']
# ------
# Chars:  ['ſ', 'e', 'i', 'd']
# Tokens:  ['ſei', 'd']
# ------
# Chars:  ['J', 'h', 'r']
# Tokens:  ['J', 'hr']
# ------
# Chars:  ['a', 'b', 'e', 'r']
# Tokens:  ['abe', 'r']
# ------
# Chars:  ['ſ', 't', 'e']
# Tokens:  ['ſte']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['ſ', 'i', 'n', 'd']
# Tokens:  ['ſi', 'nd']
# ------
# Chars:  ['t', 'e', 'i', 'l', 'h', 'a', 'f', 'f', 't', 'i', 'g']
# Tokens:  ['te', 'i', 'l', 'ha', 'ff', 'ti', 'g']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'e', 'i', 'd']
# Tokens:  ['ſei', 'd']
# ------
# Chars:  ['w', 'e', 'l', 'c', 'h', 'e', 'r']
# Tokens:  ['we', 'l', 'che', 'r']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['t', 'e', 'i', 'l', 'h', 'a', 'f', 'f', 't', 'i', 'g']
# Tokens:  ['te', 'i', 'l', 'ha', 'ff', 'ti', 'g']
# ------
# Chars:  ['w', 'o', 'r', 'd', 'e', 'n', '/']
# Tokens:  ['w', 'or', 'den', '/']
# ------
# Chars:  ['ſ', 'e', 'i', 'd']
# Tokens:  ['ſei', 'd']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['S', 'e', 'h', 'e', 't']
# Tokens:  ['S', 'eh', 'et']
# ------
# Chars:  ['a', 'n']
# Tokens:  ['an']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['n', 'i', 'c', 'h', 't']
# Tokens:  ['ni', 'cht']
# ------
# Chars:  ['K', 'i', 'n', 'd', 'e', 'r', '.']
# Tokens:  ['K', 'in', 'der', '.']
# ------
# Chars:  ['a', 'n']
# Tokens:  ['an']
# ------
# Chars:  ['E', 'x', 'e', 'm', 'p', 'l', 'a']
# Tokens:  ['E', 'x', 'em', 'p', 'l', 'a']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e', 'n']
# Tokens:  ['li', 'ebe', 'n']
# ------
# Chars:  ['H', 'e', 'y', 'l', 'i', 'g', 'e', 'n']
# Tokens:  ['H', 'e', 'y', 'li', 'gen']
# ------
# Chars:  ['w', 'e', 'l', 'c', 'h', 'e', 's']
# Tokens:  ['we', 'l', 'che', 's']
# ------
# Chars:  ['ſ', 'i', 'n', 'd']
# Tokens:  ['ſi', 'nd']
# ------
# Chars:  ['g', 'r', 'o', 'ͤ', '⸗']
# Tokens:  ['g', 'r', 'o', 'ͤ', '⸗']
# ------
# Chars:  ['w', 'e', 'l', 'c', 'h', 'e', 's']
# Tokens:  ['we', 'l', 'che', 's']
# ------
# Chars:  ['ſ', 'i', 'n', 'd']
# Tokens:  ['ſi', 'nd']
# ------
# Chars:  ['ſ', 't', 'e', 'n']
# Tokens:  ['ſte', 'n']
# ------
# Chars:  ['g', 'e', 'w', 'e', 'ſ', 'e', 'n']
# Tokens:  ['ge', 'we', 'ſen']
# ------
# Chars:  ['T', 'e', 'ſ', 't', 'a', 'm', 'e', 'n', 't', ':']
# Tokens:  ['T', 'eſ', 't', 'a', 'me', 'n', 't', ':']
# ------
# Chars:  ['H', 'e', 'y', 'l', 'i', 'g', 'e', 'n']
# Tokens:  ['H', 'e', 'y', 'li', 'gen']
# ------
# Chars:  ['D', 'e', 'r']
# Tokens:  ['D', 'er']
# ------
# Chars:  ['P', 'r', 'o', 'p', 'h', 'e', 't']
# Tokens:  ['P', 'r', 'o', 'p', 'he', 't']
# ------
# Chars:  ['E', 'z', 'e', 'c', 'h', 'i', 'e', 'l']
# Tokens:  ['E', 'z', 'e', 'ch', 'ie', 'l']
# ------
# Chars:  ['j', 'h', 'r']
# Tokens:  ['j', 'hr']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['N', 'o', 'a', 'h']
# Tokens:  ['N', 'o', 'a', 'h']
# ------
# Chars:  ['e', 'r', 'z', 'e', 'h', 'l', 'e', 't']
# Tokens:  ['er', 'z', 'eh', 'le', 't']
# ------
# Chars:  ['j', 'h', 'r']
# Tokens:  ['j', 'hr']
# ------
# Chars:  ['d', 'r', 'e', 'y', '/']
# Tokens:  ['d', 're', 'y', '/']
# ------
# Chars:  ['N', 'o', 'a', 'h', '/']
# Tokens:  ['N', 'o', 'a', 'h', '/']
# ------
# Chars:  ['D', 'a', 'n', 'i', 'e', 'l', '/']
# Tokens:  ['D', 'an', 'ie', 'l', '/']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['N', 'o', 'a', 'h']
# Tokens:  ['N', 'o', 'a', 'h']
# ------
# Chars:  ['w', 'a', 'r']
# Tokens:  ['w', 'ar']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['e', 'r']
# Tokens:  ['er']
# ------
# Chars:  ['m', 'u', 'ſ', 't', 'e']
# Tokens:  ['m', 'u', 'ſte']
# ------
# Chars:  ['J', 'o', 'b', '/']
# Tokens:  ['J', 'o', 'b', '/']
# ------
# Chars:  ['e', 'i', 'n']
# Tokens:  ['ein']
# ------
# Chars:  ['ſ', 'e', 'h', 'r']
# Tokens:  ['ſe', 'hr']
# ------
# Chars:  ['g', 'e', 'p', 'l', 'a', 'g', 't', 'e', 'r']
# Tokens:  ['ge', 'p', 'l', 'a', 'g', 'ter']
# ------
# Chars:  ['m', 'u', 'ſ', 't', 'e']
# Tokens:  ['m', 'u', 'ſte']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['B', 'u', 'ß']
# Tokens:  ['B', 'u', 'ß']
# ------
# Chars:  ['p', 'r', 'e', 'd', 'i', 'g', 'e', 'n']
# Tokens:  ['p', 're', 'di', 'gen']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['v', 'n', 't', 'e', 'r', '⸗']
# Tokens:  ['vn', 'ter', '⸗']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['e', 'r', 'ſ', 't', 'e', 'n']
# Tokens:  ['er', 'ſte', 'n']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['p', 'r', 'e', 'd', 'i', 'g', 'e', 'n', '/']
# Tokens:  ['p', 're', 'di', 'gen', '/']
# ------
# Chars:  ['v', 'n', 't', 'e', 'r', '-']
# Tokens:  ['vn', 'ter', '-']
# ------
# Chars:  ['g', 'a', 'n', 'g']
# Tokens:  ['g', 'an', 'g']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'e', 'r', 'k', 'u', 'ͤ', 'n', 'd', 'i', 'g', 'e', 'n', '/']
# Tokens:  ['ver', 'k', 'uͤ', 'nd', 'ige', 'n/']
# ------
# Chars:  ['K', 'a', 'ſ', 't', 'e', 'n']
# Tokens:  ['K', 'a', 'ſte', 'n']
# ------
# Chars:  ['d', 'a', 'r', 'u', 'ͤ', 'b', 'e', 'r']
# Tokens:  ['da', 'r', 'uͤ', 'ber']
# ------
# Chars:  ['v', 'e', 'r', 'a', 'c', 'h', 't']
# Tokens:  ['ver', 'ach', 't']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'a', 'c', 'h', 't']
# Tokens:  ['ver', 'l', 'ach', 't']
# ------
# Chars:  ['m', 'u', 'ß']
# Tokens:  ['m', 'u', 'ß']
# ------
# Chars:  ['v', 'e', 'r', 'a', 'c', 'h', 't']
# Tokens:  ['ver', 'ach', 't']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['E', 'r']
# Tokens:  ['E', 'r']
# ------
# Chars:  ['g', 'a', 'n', 't', 'z', 'e', 's']
# Tokens:  ['g', 'an', 'tz', 'es']
# ------
# Chars:  ['J', 'a', 'h', 'r']
# Tokens:  ['J', 'a', 'hr']
# ------
# Chars:  ['v', 'b', 'e', 'r']
# Tokens:  ['v', 'ber']
# ------
# Chars:  ['ſ', 'c', 'h', 'w', 'e', 'b', 'e', 'n']
# Tokens:  ['ſch', 'we', 'ben']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['J', 'a', 'h', 'r']
# Tokens:  ['J', 'a', 'hr']
# ------
# Chars:  ['d', 'e', 'm']
# Tokens:  ['de', 'm']
# ------
# Chars:  ['w', 'i', 'r', 'd']
# Tokens:  ['wi', 'r', 'd']
# ------
# Chars:  ['h', 'e', 'r', 'u', 'a', 'c', 'h']
# Tokens:  ['her', 'u', 'ach']
# ------
# Chars:  ['e', 'i', 'g', 'e', 'n', 'e', 'n']
# Tokens:  ['ei', 'gen', 'en']
# ------
# Chars:  ['S', 'o', 'h', 'n']
# Tokens:  ['S', 'o', 'h', 'n']
# ------
# Chars:  ['d', 'e', 'm']
# Tokens:  ['de', 'm']
# ------
# Chars:  ['v', 'e', 'r', '⸗']
# Tokens:  ['ver', '⸗']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', 'e', 'm']
# Tokens:  ['ſei', 'ne', 'm']
# ------
# Chars:  ['e', 'i', 'g', 'e', 'n', 'e', 'n']
# Tokens:  ['ei', 'gen', 'en']
# ------
# Chars:  ['S', 'o', 'h', 'n']
# Tokens:  ['S', 'o', 'h', 'n']
# ------
# Chars:  ['d', 'e', 'm']
# Tokens:  ['de', 'm']
# ------
# Chars:  ['v', 'e', 'r', '-']
# Tokens:  ['ver', '-']
# ------
# Chars:  ['ſ', 'p', 'o', 't', 't', 'e', 't', '.']
# Tokens:  ['ſ', 'p', 'ott', 'et', '.']
# ------
# Chars:  ['D', 'a', 'n', 'i', 'e', 'l']
# Tokens:  ['D', 'an', 'ie', 'l']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['G', 'o', 't', 't', 'e', 's']
# Tokens:  ['Got', 'te', 's']
# ------
# Chars:  ['m', 'u', 'ß']
# Tokens:  ['m', 'u', 'ß']
# ------
# Chars:  ['ſ', 'p', 'o', 't', 't', 'e', 't', '.']
# Tokens:  ['ſ', 'p', 'ott', 'et', '.']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['g', 'e', 'n']
# Tokens:  ['gen']
# ------
# Chars:  ['G', 'o', 't', 't', 'e', 's']
# Tokens:  ['Got', 'te', 's']
# ------
# Chars:  ['f', 'u', 'r', 'c', 'h', 't']
# Tokens:  ['f', 'u', 'r', 'cht']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['L', 'o', 'ͤ', 'w', 'e', 'n']
# Tokens:  ['L', 'o', 'ͤ', 'we', 'n']
# ------
# Chars:  ['g', 'r', 'a', 'b', 'e', 'n']
# Tokens:  ['g', 'ra', 'ben']
# ------
# Chars:  ['g', 'e', '⸗']
# Tokens:  ['ge', '⸗']
# ------
# Chars:  ['G', 'o', 't', 't', 'e', 's', 'f', 'u', 'r', 'c', 'h', 't']
# Tokens:  ['Got', 'te', 's', 'f', 'u', 'r', 'cht']
# ------
# Chars:  ['d', 'e', 'n']
# Tokens:  ['den']
# ------
# Chars:  ['g', 'r', 'a', 'b', 'e', 'n']
# Tokens:  ['g', 'ra', 'ben']
# ------
# Chars:  ['d', 'e', 'y', 'e', 'n', '.']
# Tokens:  ['de', 'y', 'en.']
# ------
# Chars:  ['l', 'o', 'b']
# Tokens:  ['l', 'o', 'b']
# ------
# Chars:  ['r', 'e', 'c', 'h', 't', 'e']
# Tokens:  ['re', 'cht', 'e']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'c', 'h', 'l', 'e', 'c', 'h', 't', 'e']
# Tokens:  ['ſch', 'le', 'cht', 'e']
# ------
# Chars:  ['M', 'a', 'n', 'n']
# Tokens:  ['M', 'an', 'n']
# ------
# Chars:  ['k', 'o', 'ͤ', 'm', 'p', 't']
# Tokens:  ['k', 'o', 'ͤ', 'm', 'p', 't']
# ------
# Chars:  ['d', 'e', 'y', 'e', 'n', '.']
# Tokens:  ['de', 'y', 'en.']
# ------
# Chars:  ['d', 'e', 'r']
# Tokens:  ['der']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'c', 'h', 'l', 'e', 'c', 'h', 't', 'e']
# Tokens:  ['ſch', 'le', 'cht', 'e']
# ------
# Chars:  ['M', 'a', 'n', 'n']
# Tokens:  ['M', 'an', 'n']
# ------
# Chars:  ['v', 'ñ']
# Tokens:  ['v', 'ñ']
# ------
# Chars:  ['v', 'm', 'b']
# Tokens:  ['v', 'm', 'b']
# ------
# Chars:  ['H', 'a', 'a', 'b']
# Tokens:  ['H', 'a', 'a', 'b']
# ------
# Chars:  ['v', 'ñ']
# Tokens:  ['v', 'ñ']
# ------
# Chars:  ['G', 'u', 't', 't', '/']
# Tokens:  ['G', 'u', 'tt', '/']
# ------
# Chars:  ['S', 'c', 'h', 'a', 'f', 'e', '/']
# Tokens:  ['S', 'ch', 'a', 'f', 'e', '/']
# ------
# Chars:  ['R', 'i', 'n', 'd', 'e', 'r', '/']
# Tokens:  ['R', 'in', 'der', '/']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# ...
# Chars:  ['b', 'e', 'y']
# Tokens:  ['be', 'y']
# ------
# Chars:  ['H', 'i', 'm', 'm', 'e', 'l']
# Tokens:  ['H', 'i', 'm', 'me', 'l']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'i', 'g', 'e', 'n']
# Tokens:  ['me', 'in', 'ige', 'n']
# ------
# Chars:  ['v', 'o', 'r', 'b', 'e', 't', 'e', 'n', '.']
# Tokens:  ['v', 'or', 'be', 'ten', '.']
# ------
# Chars:  ['v', 'm', 'h']
# Tokens:  ['v', 'm', 'h']
# ------
# Chars:  ['w', 'i', 'l', 'l', 'e', 'n']
# Tokens:  ['wi', 'lle', 'n']
# ------
# Chars:  ['v', 'o', 'r', 'b', 'e', 't', 'e', 'n', '.']
# Tokens:  ['v', 'or', 'be', 'ten', '.']
# ------
# Chars:  ['a', 'u', 'c', 'h']
# Tokens:  ['auc', 'h']
# ------
# Chars:  ['v', 'm', 'b']
# Tokens:  ['v', 'm', 'b']
# ------
# Chars:  ['G', 'o', 't', 't', 'e', 's']
# Tokens:  ['Got', 'te', 's']
# ------
# Chars:  ['ſ', 'o']
# Tokens:  ['ſo']
# ------
# Chars:  ['o', 'd', 'e', 'r']
# Tokens:  ['o', 'der']
# ------
# Chars:  ['a', 'n', 'd', 'e', 'r', 'e', 'm']
# Tokens:  ['and', 'er', 'em']
# ------
# Chars:  ['v', 'o', 'r', 'n', 'e', 'h', 'm', 'e', 'n', '/']
# Tokens:  ['v', 'or', 'ne', 'h', 'me', 'n/']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['l', 'e', 'b']
# Tokens:  ['le', 'b']
# ------
# Chars:  ['e', 'n']
# Tokens:  ['en']
# ------
# Chars:  ['a', 'n', 'd', 'e', 'r', 'e', 'm']
# Tokens:  ['and', 'er', 'em']
# ------
# Chars:  ['v', 'o', 'r', 'n', 'e', 'h', 'm', 'e', 'n', '/']
# Tokens:  ['v', 'or', 'ne', 'h', 'me', 'n/']
# ------
# Chars:  ['w', 'i', 'e']
# Tokens:  ['wie']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['g', 'e', 'a', 'ͤ', 'r', 'g', 'e', 'r', 't']
# Tokens:  ['ge', 'a', 'ͤ', 'r', 'ge', 'rt']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['o', 'd', 'e', 'r']
# Tokens:  ['o', 'der']
# ------
# Chars:  ['w', 'i', 'e']
# Tokens:  ['wie']
# ------
# Chars:  ['m', 'i', 'r']
# Tokens:  ['mi', 'r']
# ------
# Chars:  ['n', 'i', 't']
# Tokens:  ['ni', 't']
# ------
# Chars:  ['w', 'i', 'ſ', 'ſ', 'e', 'n', 't', 'l', 'i', 'c', 'h', '/']
# Tokens:  ['wi', 'ſſe', 'n', 't', 'lic', 'h', '/']
# ------
# Chars:  ['g', 'e', 'a', 'ͤ', 'r', 'g', 'e', 'r', 't', '/']
# Tokens:  ['ge', 'a', 'ͤ', 'r', 'ge', 'rt', '/']
# ------
# Chars:  ['o', 'd', 'e', 'r']
# Tokens:  ['o', 'der']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'e', 's', 'g', 'l']
# Tokens:  ['de', 's', 'g', 'l']
# ------
# Chars:  ['h', 'a', 'b', 'e']
# Tokens:  ['ha', 'be']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['m', 'a', 'ͤ', 'n', 'n', 'i', 'g', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['m', 'a', 'ͤ', 'nn', 'ig', 'lic', 'hen']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'o', 'n', 'd', 'e', 'r', '⸗']
# Tokens:  ['ſo', 'nde', 'r', '⸗']
# ------
# Chars:  ['h', 'e', 't', 't', 'e', '/']
# Tokens:  ['he', 'tte', '/']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['a', 'b', 'g', 'o', 'ͤ', 'n', 'ſ', 't', 'i', 'g']
# Tokens:  ['a', 'b', 'g', 'o', 'ͤ', 'n', 'ſt', 'ig']
# ------
# Chars:  ['g', 'e', 'w', 'e', 'ſ', 'e', 'n']
# Tokens:  ['ge', 'we', 'ſen']
# ------
# Chars:  ['w', 'i', 'e']
# Tokens:  ['wie']
# ------
# Chars:  ['e', 's']
# Tokens:  ['es']
# ------
# Chars:  ['w', 'i', 'e', 'd', 'e', 'r', 'w', 'e', 'r', 't', 'i', 'g']
# Tokens:  ['wie', 'der', 'we', 'rt', 'ig']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['a', 'b', 'g', 'o', 'ͤ', 'n', 'ſ', 't', 'i', 'g']
# Tokens:  ['a', 'b', 'g', 'o', 'ͤ', 'n', 'ſt', 'ig']
# ------
# Chars:  ['g', 'e', 'w', 'e', 'ſ', 'e', 'n', '/']
# Tokens:  ['ge', 'we', 'ſen', '/']
# ------
# Chars:  ['w', 'i', 'e']
# Tokens:  ['wie']
# ------
# Chars:  ['e', 's']
# Tokens:  ['es']
# ------
# Chars:  ['j', 'h', 'n', 'e', 'n']
# Tokens:  ['j', 'h', 'nen']
# ------
# Chars:  ['ſ', 'a', 'g', 'e', 'n']
# Tokens:  ['ſ', 'a', 'gen']
# ------
# Chars:  ['h', 'e', 'r', 't', 'z', 'e', 'n', 's']
# Tokens:  ['her', 'tz', 'en', 's']
# ------
# Chars:  ['v', 'e', 'r', 'z', 'i', 'e', 'h', 'e', 'n', '.']
# Tokens:  ['ver', 'z', 'ie', 'hen', '.']
# ------
# Chars:  ['ſ', 'a', 'g', 'e', 'n']
# Tokens:  ['ſ', 'a', 'gen']
# ------
# Chars:  ['w', 'i', 'r', 'd', '/']
# Tokens:  ['wi', 'r', 'd', '/']
# ------
# Chars:  ['v', 'o', 'n']
# Tokens:  ['v', 'on']
# ------
# Chars:  ['g', 'r', 'u', 'n', 'd']
# Tokens:  ['g', 'r', 'und']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e', 's']
# Tokens:  ['me', 'ine', 's']
# ------
# Chars:  ['E', 'n', 'd', 't', 'l', 'i', 'c', 'h']
# Tokens:  ['E', 'nd', 't', 'lic', 'h']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['m', 'e', 'i', 'n']
# Tokens:  ['me', 'in']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e', 's']
# Tokens:  ['li', 'ebe', 's']
# ------
# Chars:  ['g', 'e', 'ſ', 'e', 'g', 'n', 'e']
# Tokens:  ['ge', 'ſe', 'g', 'ne']
# ------
# Chars:  ['i', 'c', 'h']
# Tokens:  ['ich']
# ------
# Chars:  ['h', 'i', 'e', 'm', 'i', 't']
# Tokens:  ['h', 'ie', 'mit']
# ------
# Chars:  ['h', 'i', 'n', 't', 'e', 'r', 'l', 'a', 'ſ', 'ſ', 'e', 'n', 'e', 's']
# Tokens:  ['h', 'in', 'ter', 'l', 'a', 'ſſe', 'ne', 's']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e', 's']
# Tokens:  ['li', 'ebe', 's']
# ------
# Chars:  ['W', 'e', 'i', 'b']
# Tokens:  ['W', 'ei', 'b']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['K', 'i', 'n', 'd', 'e', 'r']
# Tokens:  ['K', 'in', 'der']
# ------
# Chars:  ['m', 'i', 'c', 'h']
# Tokens:  ['mi', 'ch']
# ------
# Chars:  ['v', 'o', 'n']
# Tokens:  ['v', 'on']
# ------
# Chars:  ['W', 'e', 'i', 'b', '/']
# Tokens:  ['W', 'ei', 'b', '/']
# ------
# Chars:  ['d', 'e', 'r', 'e', 'r']
# Tokens:  ['der', 'er']
# ------
# Chars:  ['z', 'e', 'i', 't', 'l', 'i', 'c', 'h']
# Tokens:  ['z', 'eit', 'lic', 'h']
# ------
# Chars:  ['m', 'i', 'c', 'h']
# Tokens:  ['mi', 'ch']
# ------
# Chars:  ['h', 'e', 'r', 't', 'z', 'e', 'n']
# Tokens:  ['her', 'tz', 'en']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['B', 'r', 'u', 'ͤ', 'd', 'e', 'r']
# Tokens:  ['B', 'r', 'uͤ', 'der']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['h', 'e', 'r', 't', 'z', 'e', 'n']
# Tokens:  ['her', 'tz', 'en']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['m', 'e', 'i', 'n', 'e']
# Tokens:  ['me', 'ine']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['b', 'l', 'u', 't', 's']
# Tokens:  ['b', 'l', 'u', 't', 's']
# ------
# Chars:  ['E', 'i', 'd', 'm', 'a', 'ͤ', 'n', 'n', 'e', 'r', '/']
# Tokens:  ['E', 'i', 'd', 'm', 'a', 'ͤ', 'nn', 'er', '/']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['b', 'l', 'u', 't', 's']
# Tokens:  ['b', 'l', 'u', 't', 's']
# ------
# Chars:  ['f', 't', 'e', 'u', 'n', 'd', 'e']
# Tokens:  ['f', 'te', 'und', 'e']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['j', 'h', 'n', 'e', 'n']
# Tokens:  ['j', 'h', 'nen']
# ------
# Chars:  ['E', 'h', 'l', 'i', 'c', 'h', 'e']
# Tokens:  ['E', 'h', 'lic', 'he']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['B', 'r', 'u', 'ͤ', '⸗']
# Tokens:  ['B', 'r', 'uͤ', '⸗']
# ------
# Chars:  ['f', 'r', 'e', 'u', 'n', 'd', 'e', '/']
# Tokens:  ['f', 're', 'und', 'e', '/']
# ------
# Chars:  ['E', 'h', 'l', 'i', 'c', 'h', 'e', '/']
# Tokens:  ['E', 'h', 'lic', 'he', '/']
# ------
# Chars:  ['B', 'r', 'u', 'ͤ', '-']
# Tokens:  ['B', 'r', 'uͤ', '-']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['t', 'r', 'e', 'w', 'h', 'e', 'r', 't', 'z', 'i', 'g', 'e']
# Tokens:  ['t', 're', 'w', 'her', 'tz', 'ige']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['t', 'r', 'e', 'w', 'e']
# Tokens:  ['t', 're', 'we']
# ------
# Chars:  ['m', 'i', 't']
# Tokens:  ['mit']
# ------
# Chars:  ['d', 'e', 'r', 'l', 'i', 'c', 'h', 'e', '/']
# Tokens:  ['der', 'lic', 'he', '/']
# ------
# Chars:  ['f', 'r', 'e', 'u', 'n', 'd', 'l', 'i', 'c', 'h', 'e']
# Tokens:  ['f', 're', 'und', 'lic', 'he']
# ------
# Chars:  ['t', 'r', 'e', 'w', 'h', 'e', 'r', 't', 'z', 'i', 'g', 'e']
# Tokens:  ['t', 're', 'w', 'her', 'tz', 'ige']
# ------
# Chars:  ['l', 'i', 'e', 'b', 'e']
# Tokens:  ['li', 'ebe']
# ------
# Chars:  ['z', 'e', 'i', 't', 'l', 'i', '-']
# Tokens:  ['z', 'eit', 'li', '-']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['e', 'w', 'i', 'g', 'e', 'r']
# Tokens:  ['e', 'wi', 'ge', 'r']
# ------
# Chars:  ['v', 'o', 'r', 'g', 'e', 'l', 't', 'u', 'n', 'g']
# Tokens:  ['v', 'or', 'ge', 'l', 't', 'un', 'g']
# ------
# Chars:  ['E', 'r']
# Tokens:  ['E', 'r']
# ------
# Chars:  ['w', 'o', 'l', 'l', 'e']
# Tokens:  ['w', 'o', 'lle']
# ------
# Chars:  ['n', 'u', 'n']
# Tokens:  ['n', 'un']
# ------
# Chars:  ['c', 'h', 'e', 'r']
# Tokens:  ['che', 'r']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['v', 'o', 'r', 'g', 'e', 'l', 't', 'u', 'n', 'g', '/']
# Tokens:  ['v', 'or', 'ge', 'l', 't', 'un', 'g', '/']
# ------
# Chars:  ['j', 'h', 'r']
# Tokens:  ['j', 'hr']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['B', 'r', 'u', 'd', 'e', 'r']
# Tokens:  ['B', 'r', 'u', 'der']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['M', 'a', 'n', 'n', '/']
# Tokens:  ['M', 'an', 'n/']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['B', 'r', 'u', 'd', 'e', 'r']
# Tokens:  ['B', 'r', 'u', 'der']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['b', 'l', 'e', 'i', 'b', 'e', 'n', '/']
# Tokens:  ['b', 'lei', 'ben', '/']
# ------
# Chars:  ['ſ', 'i', 'e']
# Tokens:  ['ſie']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', 'e', 'r']
# Tokens:  ['ſei', 'ne', 'r']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['a', 'n']
# Tokens:  ['an']
# ------
# Chars:  ['e', 'i', 'n', 'e', 'm']
# Tokens:  ['ein', 'em']
# ------
# Chars:  ['t', 'r', 'e', 'w', 'e', 'n']
# Tokens:  ['t', 're', 'we', 'n']
# ------
# Chars:  ['h', 'e', 'r', 't', 'z', 'e', 'n']
# Tokens:  ['her', 'tz', 'en']
# ------
# Chars:  ['ſ', 't', 'e', 'h', 'e', 't']
# Tokens:  ['ſte', 'he', 't']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'c', 'h', 'u', 'ͤ', 't', 'z', 'e', 'n']
# Tokens:  ['ſch', 'uͤ', 'tz', 'en']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['e', 'r', '⸗']
# Tokens:  ['er', '⸗']
# ------
# Chars:  ['ſ', 'e', 'i', 'n', 'e', 'r']
# Tokens:  ['ſei', 'ne', 'r']
# ------
# Chars:  ['h', 'a', 'n', 'd', '/']
# Tokens:  ['ha', 'nd', '/']
# ------
# Chars:  ['d', 'i', 'e']
# Tokens:  ['die']
# ------
# Chars:  ['a', 'n']
# Tokens:  ['an']
# ------
# Chars:  ['e', 'i', 'n', 'e', 'm']
# Tokens:  ['ein', 'em']
# ------
# Chars:  ['t', 'r', 'e', 'w', 'e', 'n']
# Tokens:  ['t', 're', 'we', 'n']
# ------
# Chars:  ['ſ', 't', 'e', 'h', 'e', 't', '/']
# Tokens:  ['ſte', 'he', 't/']
# ------
# Chars:  ['e', 'r', '-']
# Tokens:  ['er', '-']
# ------
# Chars:  ['h', 'a', 'l', 't']
# Tokens:  ['ha', 'l', 't']
# ------
# Chars:  ['e', 'n']
# Tokens:  ['en']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['v', 'e', 'r', 'ſ', 'o', 'r', 'g', 'e', 'n']
# Tokens:  ['ver', 'ſo', 'r', 'gen']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'e', 'i', 'h', 'e', 'n']
# Tokens:  ['ver', 'lei', 'hen']
# ------
# Chars:  ['d', 'a', 's']
# Tokens:  ['das']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['j', 'e', 'n', 'e', 'm']
# Tokens:  ['j', 'en', 'em']
# ------
# Chars:  ['h', 'a', 'l', 't', 'e', 'n']
# Tokens:  ['ha', 'l', 'ten']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['v', 'e', 'r', 'l', 'e', 'i', 'h', 'e', 'n', '/']
# Tokens:  ['ver', 'lei', 'hen', '/']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['E', 'h', 'r', 'e', 'n']
# Tokens:  ['E', 'hre', 'n']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['m', 'o', 'g', 'e', 'n']
# Tokens:  ['m', 'o', 'gen']
# ------
# Chars:  ['i', 'n']
# Tokens:  ['in']
# ------
# Chars:  ['e', 'w', 'i', 'g', 'e', 'n']
# Tokens:  ['e', 'wi', 'gen']
# ------
# Chars:  ['E', 'h', 'r', 'e', 'n']
# Tokens:  ['E', 'hre', 'n']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['f', 'r', 'e', 'u', 'd', 'e', 'n', '/']
# Tokens:  ['f', 're', 'u', 'den', '/']
# ------
# Chars:  ['a', 'l', 'l', 'e']
# Tokens:  ['all', 'e']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r', 's']
# Tokens:  ['vn', 'ſe', 'r', 's']
# ------
# Chars:  ['ſ', 'c', 'h', 'm', 'e', 'r', 't', 'z', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['ſch', 'me', 'rt', 'z', 'lic', 'hen']
# ------
# Chars:  ['l', 'e', 'i', 'd', 'e', 'n', 's']
# Tokens:  ['lei', 'den', 's']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['ſ', 'c', 'h', 'e', 'i', 'd', 'e', 'n', 's']
# Tokens:  ['ſch', 'ei', 'den', 's']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['d', 'a', 'ſ', 'e', 'l', 'b', 'ſ', 't']
# Tokens:  ['da', 'ſe', 'l', 'b', 'ſt']
# ------
# Chars:  ['v', 'n', 'ſ', 'e', 'r', 's']
# Tokens:  ['vn', 'ſe', 'r', 's']
# ------
# Chars:  ['ſ', 'c', 'h', 'm', 'e', 'r', 't', 'z', 'l', 'i', 'c', 'h', 'e', 'n']
# Tokens:  ['ſch', 'me', 'rt', 'z', 'lic', 'hen']
# ------
# Chars:  ['ſ', 'c', 'h', 'e', 'i', 'd', 'e', 'n', 's']
# Tokens:  ['ſch', 'ei', 'den', 's']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['w', 'e', 'r', 'd', 'e', 'n', '.']
# Tokens:  ['we', 'r', 'den', '.']
# ------
# Chars:  ['r', 'e', 'i', 'c', 'h', 'l', 'i', 'c', 'h']
# Tokens:  ['re', 'ich', 'lic', 'h']
# ------
# Chars:  ['e', 'r', 'g', 'e', 't', 'z', 'e', 't']
# Tokens:  ['er', 'ge', 'tz', 'et']
# ------
# Chars:  ['N', 'u', 'n']
# Tokens:  ['N', 'un']
# ------
# Chars:  ['g', 'e', 'ſ', 'e', 'g', 'n', 'e']
# Tokens:  ['ge', 'ſe', 'g', 'ne']
# ------
# Chars:  ['e', 'u', 'c', 'h']
# Tokens:  ['e', 'uch']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'e']
# Tokens:  ['H', 'E', 'r', 're']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['e', 'u', 'c', 'h']
# Tokens:  ['e', 'uch']
# ------
# Chars:  ['H', 'E', 'r', 'r', 'e']
# Tokens:  ['H', 'E', 'r', 're']
# ------
# Chars:  ['m', 'e', 'i', 'n', '/']
# Tokens:  ['me', 'in', '/']
# ------
# Chars:  ['J', 'h', 'r']
# Tokens:  ['J', 'hr']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['S', 'c', 'h', 'w', 'e', 'ſ', 't', 'e', 'r', 'n']
# Tokens:  ['S', 'ch', 'we', 'ſte', 'r', 'n']
# ------
# Chars:  ['J', 'h', 'r']
# Tokens:  ['J', 'hr']
# ------
# Chars:  ['v', 'n', 'd']
# Tokens:  ['vnd']
# ------
# Chars:  ['S', 'c', 'h', 'w', 'e', 'ſ', 't', 'e', 'r', 'n']
# Tokens:  ['S', 'ch', 'we', 'ſte', 'r', 'n']
# ------
# Chars:  ['m', 'e', 'i', 'n', '.']
# Tokens:  ['me', 'in', '.']
# ------
# Chars:  ['D', 'i', 'e']
# Tokens:  ['D', 'ie']
# ------
# Chars:  ['S', 'c', 'h', 'l', 'a', 'f', 'f', 'k', 'a', 'ͤ', 'm', 'm', 'e', 'r', 'l', 'e', 'i', 'n']
# Tokens:  ['S', 'ch', 'l', 'a', 'ff', 'k', 'a', 'ͤ', 'm', 'me', 'r', 'lei', 'n']
# ------
# Chars:  ['/']
# Tokens:  ['/']
# ------
# Chars:  ['D', 'i', 'e']
# Tokens:  ['D', 'ie']
# ------
# Chars:  ['m', 'e', 'i', 'n']
# Tokens:  ['me', 'in']
# ------
# Chars:  ['A', 'u', 'ß']
# Tokens:  ['A', 'u', 'ß']
# ------
# Chars:  ['l', 'i', 'e', 'b']
# Tokens:  ['li', 'eb']
# ------
# Chars:  ['m', 'i', 'c', 'h']
# Tokens:  ['mi', 'ch']
# ------
# Chars:  ['h', 'a', 'b', 't']
# Tokens:  ['ha', 'b', 't']
# ------
# Chars:  ['f', 'e', 'i', 'n', '.']
# Tokens:  ['f', 'ein', '.']
# ------
# Chars:  ['A', 'u', 'ß']
# Tokens:  ['A', 'u', 'ß']
# ------
# Chars:  ['l', 'i', 'e', 'b']
# Tokens:  ['li', 'eb']
# ------
# Chars:  ['H', 'i', 'l', 'f', 'f']
# Tokens:  ['H', 'i', 'l', 'ff']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['G', 'o', 't', 't']
# Tokens:  ['Got', 't']
# ------
# Chars:  ['w', 'i', 'r']
# Tokens:  ['wi', 'r']
# ------
# Chars:  ['z', 'u', 'g', 'l', 'e', 'i', 'c', 'h', '.']
# Tokens:  ['zu', 'g', 'lei', 'ch', '.']
# ------
# Chars:  ['E', 'i', 'n', 'a', 'n', 'd', 'e', 'r']
# Tokens:  ['E', 'in', 'and', 'er']
# ------
# Chars:  ['w', 'i', 'e', 'd', 'e', 'r']
# Tokens:  ['wie', 'der']
# ------
# Chars:  ['ſ', 'e', 'h', 'e', 'n']
# Tokens:  ['ſe', 'hen']
# ------
# Chars:  ['z', 'u', 'g', 'l', 'e', 'i', 'c', 'h', '.']
# Tokens:  ['zu', 'g', 'lei', 'ch', '.']

# %%
np.save(encoded_ocr_path, ocr_encodings)
np.save(encoded_gt_path, gt_encodings)
